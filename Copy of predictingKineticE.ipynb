# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import fetch_california_housing
from sklearn.preprocessing import StandardScaler
from torchvision import datasets, transforms

import copy
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import tqdm

# %%
N, D_in, D_out = 1000, 2, 1


# m =1
X2 = []
y2 = []
for j in range(N):
    X2.append([])
    #y.append([])
    for i in range(D_out):
        X2[-1].append( 1 )
        X2[-1].append( np.random.uniform(low=-1000.0, high=1000.0, size=None) )
        y2.append( (X2[-1][-1]**2) / (2*X2[-1][-2])  )


X2 = torch.Tensor(X2)
y2 = torch.Tensor(y2)


# p =1
X3 = []
y3 = []
for j in range(N):
    X3.append([])
    #y.append([])
    for i in range(D_out):
        X3[-1].append( np.random.uniform(low=0.0, high=10.0, size=None) )
        X3[-1].append( 1 )
        y3.append( (X3[-1][-1]**2) / (2*X3[-1][-2])  )


X3 = torch.Tensor(X3)
y3 = torch.Tensor(y3)

# X2_test = torch.tensor(X2, dtype=torch.float32)
# y2_test = torch.tensor(y2, dtype=torch.float32).reshape(-1, 1)
# X3_test = torch.tensor(X3, dtype=torch.float32)
# y3_test = torch.tensor(y3, dtype=torch.float32).reshape(-1, 1)

# %%
plt.scatter(X2[:,1] ,y2, marker='.', )
plt.show()
plt.scatter(X3[:,0] ,y3, marker='.', )
plt.show()

# %%
X = torch.load('/content/drive/MyDrive/0_318lab/SCMP_ML/KEdataX_1000_1690897080.8460803.pt')
y = torch.load('/content/drive/MyDrive/0_318lab/SCMP_ML/KEdataY_1000_1690897080.8489494.pt')
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, shuffle=False)
# X2_train, X2_test, y2_train, y2_test = train_test_split(X, y, train_size=0.7, shuffle=True)
# X3_train, X3_test, y3_train, y3_test = train_test_split(X, y, train_size=0.7, shuffle=True)

# Convert to 2D PyTorch tensors
#X_train = torch.tensor(X_train, dtype=torch.float32)
#y_train = torch.tensor(y_train, dtype=torch.float32).reshape(-1, 1)
#X_test = torch.tensor(X_test, dtype=torch.float32)
#y_test = torch.tensor(y_test, dtype=torch.float32).reshape(-1, 1)

# %%
#default

"""
optimizer: Adadelta , n_of_data: 1000 , Bsize: 10 , learningRate: 0.5 , minimum_RMSE: 823.27 , epoch:  1000 , test_loss:   823 , train_loss:    30 , layer_dim_list: [2, 16, 8, 1]
optimizer: Adamax , n_of_data: 1000 , Bsize: 10 , learningRate: 0.001 , minimum_RMSE: 959.64 , epoch:  1000 , test_loss:   960 , train_loss:    48 , layer_dim_list: [2, 16, 8, 1]
optimizer: AdamW , n_of_data: 1000 , Bsize: 500 , learningRate: 0.0005 , minimum_RMSE: 1270.51 , epoch:  1000 , test_loss:  1270 , train_loss:   300 , layer_dim_list: [2, 16, 8, 1]
optimizer: AdamW , n_of_data: 1000 , Bsize: 500 , learningRate: 0.001 , minimum_RMSE: 1210.68 , epoch:  1000 , test_loss:  1210 , train_loss:   282 , layer_dim_list: [2, 16, 8, 1]
optimizer: AdamW , n_of_data: 1000 , Bsize: 100 , learningRate: 0.005 , minimum_RMSE: 890.75 , epoch:  1000 , test_loss:   908 , train_loss:   341 , layer_dim_list: [2, 16, 8, 1]
optimizer: Adam , n_of_data: 1000 , Bsize: 500 , learningRate: 5e-06 , minimum_RMSE: 1143.49 , epoch:  1000 , test_loss:  1143 , train_loss:   891 , layer_dim_list: [2, 16, 8, 1]

"""
# for learningRate in range(10): #


dim_list = [2, 16, 16,16, 8, 1]



#If data is less complex and is having fewer dimensions or features then neural networks with 1 to 2 hidden layers would work.
# If data is having large dimensions or features then to get an optimum solution, 3 to 5 hidden layers can be used.


# for Bsize in [500]:
# for opt in [
#             'Adadelta',
#             'Adagrad',
#             'Adam',
#             'AdamW',
#             'SparseAdam',x
#             'Adamax',
#             'ASGD',x
#             'LBFGS',x
#             'NAdam',
#             'RAdam',x
#             'RMSprop',
#             'Rprop',
#             'SGD'x
#             ]:
for opt in [
            # 'Adadelta',
            # 'Adagrad',
            'Adam',
            # 'AdamW',
            # 'SparseAdam',
            # 'Adamax',
            # 'ASGD',
            # 'LBFGS',
            # 'NAdam',
            # 'RAdam',
            # 'RMSprop',
            # 'Rprop',
            # 'SGD'
            ]:
    try:
        # if opt == 'Adam':# ---------------delete later----------------------------------------------------------------------------------------------------------------------------------------------
        #     continue# ---------------delete later----------------------------------------------------------------------------------------------------------------------------------------------
        for Bsize in [ 100 ]:
        # for Bsize in [ 50]:
            # print('Bsize:', Bsize, end =' ')
            #before_loss_twos =  torch.ones(Bsize, dtype=torch.float32)*2
            for learningRate in [ 5e-3  ]:
            # for learningRate in [   1e-6, ]:
                # print('learningRate:', learningRate)
                # Define the model

                make_model = 'model = nn.Sequential('
                for layer_num in range( len(dim_list) - 1 ):
                    if layer_num == len(dim_list) - 2:
                        make_model = make_model + 'nn.Linear(dim_list[' + str(layer_num) + '], dim_list[' + str(layer_num+1) + ']) )'
                    else:
                        make_model = make_model + 'nn.Linear(dim_list[' + str(layer_num) + '], dim_list[' + str(layer_num+1) + ']), nn.LeakyReLU(),'

                exec(make_model)
                #make_model = make_model +

                # model = nn.Sequential(
                #     nn.Linear(dim_list[0], dim_list[1]),
                #     nn.LeakyReLU(),
                #     nn.Linear(dim_list[1], dim_list[2]),
                #     nn.LeakyReLU(),
                #     nn.Linear(dim_list[2], dim_list[3])
                #     # nn.Linear(2, 3),
                #     # nn.LeakyReLU(),
                #     # nn.Linear(3, 2),
                #     # nn.LeakyReLU(),
                #     # nn.Linear(2, 1)
                # )

                # loss function and optimizer
                loss_fn = nn.MSELoss()  # mean square error
                # optimizer = optim.Adam(model.parameters(), lr=learningRate  )  # 10 loss: 5157042688.0
                exec('optimizer = optim.' + opt + '(model.parameters(), lr=learningRate  )')
                n_epochs = 10000+1   # number of epochs to run
                batch_size = Bsize  # size of each batch
                batch_start = torch.arange(0, len(X_train), batch_size)

                # Hold the best model
                best_mse = np.inf   # init to infinity
                best_weights = None
                history = []
                history_train = []
                for epoch in range(n_epochs):
                    model.train()
                    with tqdm.tqdm(batch_start, unit="batch", mininterval=0, disable=True) as bar:
                        bar.set_description(f"Epoch {epoch}")
                        for start in bar:
                            # take a batch
                            X_batch = X_train[start:start+batch_size]
                            y_batch = y_train[start:start+batch_size]
                            # forward pass
                            y_pred = model(X_batch)

                            before_loss = y_pred/y_batch + y_batch/y_pred
                            before_loss_twos =  torch.ones(len(y_pred), dtype=torch.float32)*2


                            loss = loss_fn(before_loss, before_loss_twos)
                            # backward pass
                            optimizer.zero_grad()
                            loss.backward()
                            # update weights
                            optimizer.step()
                            # print progress
                            bar.set_postfix(mse=float(loss))
                    #print(y_pred)
                    loss = float(loss)

                    history_train.append(loss)
                    # evaluate accuracy at end of each epoch
                    model.eval()
                    y_pred = model(X_test)
                    #print(y_pred)
                    before_loss = y_pred/y_test + y_test/y_pred
                    before_loss_twos =  torch.ones(len(y_pred), dtype=torch.float32)*2
                    mse = loss_fn(before_loss, before_loss_twos)

                    mse = float(mse)

                    history.append(mse)
                    if mse < best_mse:
                        best_mse = mse
                        best_weights = copy.deepcopy(model.state_dict())

                    if epoch % 100 == 0:
                        print('epoch: %5d' % epoch, 'test_loss: %5d' % np.sqrt(mse), 'train_loss: %5d' % np.sqrt(loss))

                # restore model and return best accuracy
                model.load_state_dict(best_weights)
                # print("MSE: %.2f" % best_mse)
                # print("RMSE: %.2f" % np.sqrt(best_mse))
                print('optimizer:', opt, ', n_of_data:',N, ', Bsize:', Bsize ,', learningRate:', learningRate , ", minimum_RMSE: %.2f" % np.sqrt(best_mse), ', epoch: %5d' % epoch, ', test_loss: %5d' % np.sqrt(mse), ', train_loss: %5d' % np.sqrt(loss), ', layer_dim_list:', dim_list  )
                # print(y_pred[:10])
                # print(y_test[:10])
                plt.plot(history)
                plt.yscale('log')
                plt.title('test_loss')
                plt.show()

                plt.plot(history_train)
                plt.title('train_loss')
                plt.yscale('log')
                plt.show()
    except:
        print('error when:', opt, 'error when:', opt, 'error when:', opt, 'error when:', opt, 'error when:', opt, 'error when:', opt, 'error when:', opt, 'error when:', opt, 'error when:', opt, 'error when:', opt, 'error when:', opt, )
print('all done')
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Out:
# epoch:     0 test_loss:  1150 train_loss:   583
# epoch:   100 test_loss:  1060 train_loss:   349
# epoch:   200 test_loss:   919 train_loss:   327
# epoch:   300 test_loss:   896 train_loss:   328
# epoch:   400 test_loss:   888 train_loss:   332
# epoch:   500 test_loss:   893 train_loss:   328
# epoch:   600 test_loss:   892 train_loss:   329
# epoch:   700 test_loss:   880 train_loss:   328
# epoch:   800 test_loss:   884 train_loss:   328
# epoch:   900 test_loss:   879 train_loss:   327
# epoch:  1000 test_loss:   884 train_loss:   323
# epoch:  1100 test_loss:   931 train_loss:   332
# epoch:  1200 test_loss:   904 train_loss:   328
# epoch:  1300 test_loss:   900 train_loss:   323
# epoch:  1400 test_loss:   896 train_loss:   324
# epoch:  1500 test_loss:   909 train_loss:   322
# epoch:  1600 test_loss:   896 train_loss:   320
# epoch:  1700 test_loss:   898 train_loss:   319
# epoch:  1800 test_loss:   924 train_loss:   319
# epoch:  1900 test_loss:   892 train_loss:   317
# epoch:  2000 test_loss:   891 train_loss:   314
# epoch:  2100 test_loss:   890 train_loss:   325
# epoch:  2200 test_loss:   894 train_loss:   320
# epoch:  2300 test_loss:   885 train_loss:   317
# epoch:  2400 test_loss:   886 train_loss:   314
# epoch:  2500 test_loss:   884 train_loss:   308
# epoch:  2600 test_loss:   892 train_loss:   309
# epoch:  2700 test_loss:  1462 train_loss:  1314
# epoch:  2800 test_loss:  4119 train_loss:   751
# epoch:  2900 test_loss:  4051 train_loss:   595
# epoch:  3000 test_loss:  2120 train_loss:   537
# epoch:  3100 test_loss:  1455 train_loss:   493
# epoch:  3200 test_loss:  1304 train_loss:   469
# epoch:  3300 test_loss:  1193 train_loss:   454
# epoch:  3400 test_loss:  1154 train_loss:   434
# epoch:  3500 test_loss:  1114 train_loss:   424
# epoch:  3600 test_loss:  1107 train_loss:   410
# epoch:  3700 test_loss:  1078 train_loss:   409
# epoch:  3800 test_loss:  1061 train_loss:   410
# epoch:  3900 test_loss:  1061 train_loss:   405
# epoch:  4000 test_loss:  1049 train_loss:   409
# epoch:  4100 test_loss:  1035 train_loss:   422
# epoch:  4200 test_loss:  1031 train_loss:   420
# epoch:  4300 test_loss:  1355 train_loss:  1105
# epoch:  4400 test_loss:  1256 train_loss:  1027
# epoch:  4500 test_loss:  1180 train_loss:   939
# epoch:  4600 test_loss:  1243 train_loss:   843
# epoch:  4700 test_loss:  1209 train_loss:   747
# epoch:  4800 test_loss:  1189 train_loss:   658
# epoch:  4900 test_loss:  1070 train_loss:   580
# epoch:  5000 test_loss:  1041 train_loss:   524
# epoch:  5100 test_loss:  1050 train_loss:   500
# epoch:  5200 test_loss:  1206 train_loss:   404
# epoch:  5300 test_loss:  1214 train_loss:   382
# epoch:  5400 test_loss:  1131 train_loss:   370
# epoch:  5500 test_loss:  1109 train_loss:   365
# epoch:  5600 test_loss:  1090 train_loss:   362
# epoch:  5700 test_loss:  1073 train_loss:   357
# epoch:  5800 test_loss:  1062 train_loss:   351
# epoch:  5900 test_loss:  1040 train_loss:   348
# epoch:  6000 test_loss:  1019 train_loss:   347
# epoch:  6100 test_loss:  1004 train_loss:   347
# epoch:  6200 test_loss:   984 train_loss:   348
# epoch:  6300 test_loss:   961 train_loss:   346
# epoch:  6400 test_loss:   955 train_loss:   342
# epoch:  6500 test_loss:   949 train_loss:   343
# epoch:  6600 test_loss:   935 train_loss:   344
# epoch:  6700 test_loss:   932 train_loss:   343
# epoch:  6800 test_loss:   925 train_loss:   335
# epoch:  6900 test_loss:   911 train_loss:   335
# epoch:  7000 test_loss:   922 train_loss:   331
# epoch:  7100 test_loss:   930 train_loss:   327
# epoch:  7200 test_loss:   942 train_loss:   321
# epoch:  7300 test_loss:   896 train_loss:   337
# epoch:  7400 test_loss:   907 train_loss:   329
# epoch:  7500 test_loss:   912 train_loss:   327
# epoch:  7600 test_loss:   900 train_loss:   332
# epoch:  7700 test_loss:   928 train_loss:   324
# epoch:  7800 test_loss:   933 train_loss:   320
# epoch:  7900 test_loss:   930 train_loss:   328
# epoch:  8000 test_loss:   925 train_loss:   320
# epoch:  8100 test_loss:   905 train_loss:   323
# epoch:  8200 test_loss:   912 train_loss:   329
# epoch:  8300 test_loss:   899 train_loss:   329
# epoch:  8400 test_loss:   922 train_loss:   325
# epoch:  8500 test_loss:   901 train_loss:   327
# epoch:  8600 test_loss:  1855 train_loss:   325
# epoch:  8700 test_loss:   915 train_loss:   329
# epoch:  8800 test_loss:   948 train_loss:   326
# epoch:  8900 test_loss:   965 train_loss:   325
# epoch:  9000 test_loss:   950 train_loss:   325
# epoch:  9100 test_loss:   883 train_loss:   333
# epoch:  9200 test_loss:   891 train_loss:   326
# epoch:  9300 test_loss:   891 train_loss:   325
# epoch:  9400 test_loss:   899 train_loss:   322
# epoch:  9500 test_loss:   881 train_loss:   325
# epoch:  9600 test_loss:   888 train_loss:   322
# epoch:  9700 test_loss:  1015 train_loss:   337
# epoch:  9800 test_loss:  1077 train_loss:   333
# epoch:  9900 test_loss:  1058 train_loss:   331
# epoch: 10000 test_loss:   970 train_loss:   330
# optimizer: Adam , n_of_data: 1000 , Bsize: 100 , learningRate: 0.005 , minimum_RMSE: 821.26 , epoch: 10000 , test_loss:   970 , train_loss:   330 , layer_dim_list: [2, 16, 16, 16, 8, 1]
# all done

# %%
model.eval()
y_pred = model(X2)
plt.scatter(X2[:,1].cpu().detach().numpy(),y_pred.cpu().detach().numpy(), marker='*')
# plt.scatter(X2[:,1],y_pred, marker='*')
plt.show()


plt.scatter(X2[:,1] ,y2, marker='.', )
plt.show()


print('all done')
# Out:
# all done

# %%
model.eval()
y_pred = model(X3)
plt.scatter(X3[:,0].cpu().detach().numpy(),y_pred.cpu().detach().numpy(), marker='*')
# plt.scatter(X3[:,1],y_pred, marker='*')
plt.show()


plt.scatter(X3[:,0] ,y3, marker='.', )
plt.show()


print('all done')
# Out:
# all done

# %%
plt.plot(history)
plt.yscale('log')
plt.title('test_loss')
plt.show()

plt.plot(history_train)
plt.title('train_loss')
plt.yscale('log')
plt.show()

# %%
# when create new data

# N, D_in, H, D_out = 64, 1000, 100, 10
N, D_in, D_out = 100000, 2, 1

# 입력과 출력 위한 랜덤 텐서
X = []
y = []
for j in range(N):
    X.append([])
    #y.append([])
    for i in range(D_out):
        X[-1].append( np.random.uniform(low=0.0, high=1000.0, size=None) )
        X[-1].append( np.random.uniform(low=-1000.0, high=1000.0, size=None) )
        y.append( (X[-1][-1]**2) / (2*X[-1][-2])  )


X = torch.Tensor(X)
y = torch.Tensor(y)

# nn package를 이용하여 여러 층으로 정의된 모델 생성
# nn.Sequential은 다른 모듈을 담을 수 있는 모듈이며 담겨진 모듈은 순서대로 연결
# Linear 모듈은 곧 Affine 모듈

# Read data
# data = fetch_california_housing()
# X, y = data.data, data.target

# train-test split for model evaluation

import time
# >>> # Save to file
# >>> x = torch.tensor([0, 1, 2, 3, 4])
# >>> torch.save(x, 'tensor.pt')

torch.save(X, 'KEdataX_'+str(time.time())+'.pt' )
torch.save(y, 'KEdataY_'+str(time.time())+'.pt' )
